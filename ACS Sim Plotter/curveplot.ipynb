# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the data
data = pd.read_csv("rk4v20_1.txt")
# For data1
sample_time = 0.01
time = np.arange(0,(data.shape[0]*sample_time),sample_time)[:]

wx = data.iloc[:,0]
wy = data.iloc[:,1]
wz = data.iloc[:,2]

mag_x = data.iloc[:,3]
mag_y = data.iloc[:,4]
mag_z = data.iloc[:,5]

wxf = data.iloc[:,6]
wyf = data.iloc[:,7]
wzf = data.iloc[:,8]

mag_xf = data.iloc[:,9]
mag_yf= data.iloc[:,10]
mag_zf = data.iloc[:,11]

# time_took  =data.iloc[:,12]

start = 0
end = 100#len(data)

# %%
time = time[start:end]

plt.figure(dpi=150)
plt.plot(time, mag_x[start:end], label = "mag_x")
plt.plot(time, mag_xf[start:end], label = "mag_xf")
# 
# plt.plot(time, mag_y[start:end], label = "mag_y")
# plt.plot(time, mag_yf[start:end], label = "mag_yf")
# 
# plt.plot(time, mag_z[start:end], label = "mag_z")
# plt.plot(time, mag_zf[start:end], label = "mag_zf")



plt.xlabel("sec")
plt.ylabel("uT")
plt.title("EKF V2 Mag")
plt.legend()
plt.show()

# %%
plt.figure(dpi=150)
plt.plot(time, wx[start:end], label = "w_x")
plt.plot(time, wxf[start:end], label = "w_xf")

plt.plot(time, wy[start:end], label = "w_y")
plt.plot(time, wyf[start:end], label = "w_yf")

plt.plot(time, wz[start:end], label = "w_zf v1")
plt.plot(time, wzf[start:end], label = "w_zf v2")


plt.xlabel("sec")
plt.ylabel("rad/s")
plt.title("EKF V2 w")
plt.legend()
plt.show()

# %%
plt.figure(dpi=150)


plt.plot(time, time_took, label = "time_took")


plt.xlabel("sec")
plt.ylabel("ms")
plt.title("EKF V2")
plt.legend()
plt.show()

print("avg time took: ", str(np.mean(time_took)), "ms")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       1 plt.figure(dpi=150)
# ----> 4 plt.plot(time, time_took, label = "time_took")
#       7 plt.xlabel("sec")
#       8 plt.ylabel("ms")
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
# ...

# %%
# Load the data
data = pd.read_csv("ekfv2rk4.txt")
# For data1
time = data.iloc[:,0]

mag_x = data.iloc[:,1]
mag_y = data.iloc[:,2]
mag_z = data.iloc[:,3]

mag_xf = data.iloc[:,4]
mag_yf = data.iloc[:,5]
mag_zf = data.iloc[:,6]

wx = data.iloc[:,7]
wy = data.iloc[:,8]
wz = data.iloc[:,9]

wxf = data.iloc[:,10]
wyf = data.iloc[:,11]
wzf = data.iloc[:,12]

# %%
plt.figure(dpi=150)
plt.plot(time,wx, label = "wz")
plt.plot(time, wxf, label = "wz_f")

# plt.plot(time, mag_x, label = "magx")
# plt.plot(time, mag_y, label = "magy")
# plt.plot(time, mag_z, label = "magz")


plt.xlabel("sec")
plt.ylabel("rad/s")
plt.title("EKF V2_rk4 w")
plt.legend()
plt.show()
