# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
data = pd.read_csv("acs_sim_ext.txt")
time =  data.iloc[:,0]

error = data.iloc[:,4]


Ix = data.iloc[:,5]
Iy = data.iloc[:,6]
Iz = data.iloc[:,7]

mag_x= data.iloc[:,8]
mag_y = data.iloc[:,9]
mag_z = data.iloc[:,10]
wx = data.iloc[:,11]
wy = data.iloc[:,12]
wz = data.iloc[:,13]

mag_xf= data.iloc[:,14]
mag_yf = data.iloc[:,15]
mag_zf = data.iloc[:,16]
wxf = data.iloc[:,17]
wyf = data.iloc[:,18]
wzf = data.iloc[:,19]



error = data.iloc[:,16]

start =0
end = len(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 time =  data.iloc[:,0]
#       3 error = data.iloc[:,4]
#       6 Ix = data.iloc[:,5]
#
# NameError: name 'data' is not defined

# %%
plt.figure(dpi=150)
plt.plot(time[start:end], wxf[start:end], label = "wxf")
# plt.plot(time, wxf[start:end], label = "wxf")
plt.plot(time[start:end], wyf[start:end], label = "wyf")
# plt.plot(time, wyf[start:end], label = "wyf")
plt.plot(time[start:end], wzf[start:end], label = "wzf")
# plt.plot(time, wzf[start:end], label = "wzf")




plt.xlabel("sec")
plt.ylabel("rad/s")
plt.title("angular velocity(ekf online)")
plt.legend()
plt.show()

# %%
plt.figure(dpi=150)
plt.plot(time[start:end], mag_x[start:end], label = "mag_x")
plt.plot(time[start:end], mag_xf[start:end], label = "mag_xf")
# plt.plot(time[start:end], mag_yf[start:end], label = "mag_yf")
# plt.plot(time[start:end],  mag_zf[start:end], label = "mag_zf")





plt.xlabel("sec")
plt.ylabel("T")
plt.title("mag(ekf online)")
plt.legend()
plt.show()

# %%
plt.figure(dpi=150)

plt.plot(time[start:end], error[start:end], label = "Iz")


plt.xlabel("sec")
plt.ylabel("deg")
plt.title("pt error")
plt.legend()
plt.show()

# %%
data = pd.read_csv("acs_sim_ext.txt")
time =  data.iloc[:,0]

error = data.iloc[:,4]


Ix = data.iloc[:,5]
Iy = data.iloc[:,6]
Iz = data.iloc[:,7]

mag_x= data.iloc[:,8]
mag_y = data.iloc[:,9]
mag_z = data.iloc[:,10]
wx = data.iloc[:,11]
wy = data.iloc[:,12]
wz = data.iloc[:,13]

mag_xf= data.iloc[:,14]
mag_yf = data.iloc[:,15]
mag_zf = data.iloc[:,16]
wxf = data.iloc[:,17]
wyf = data.iloc[:,18]
wzf = data.iloc[:,19]



error = data.iloc[:,16]

start =0
end = len(data)

plt.figure(dpi=150)

plt.plot(time, Iz[start:end], label = "Iz")


plt.xlabel("sec")
plt.ylabel("A")
plt.title("current(ekf offline)")
plt.legend()
plt.show()
