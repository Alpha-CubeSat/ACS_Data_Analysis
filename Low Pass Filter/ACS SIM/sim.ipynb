# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data.txt")

# mag_x= df.iloc[:,0]
# mag_y= df.iloc[:,1]
# mag_z= df.iloc[:,2]

# mag_z_v = mag_z/np.sqrt(mag_x*mag_x+mag_y*mag_y+mag_z*mag_z)
#
# current_z = df.iloc[:,5]
# x = np.arange(0,mag_x.size)
# t = x*0.25



t= df.iloc[:,0]/1000
error = df.iloc[:,1]
current = df.iloc[:,2]

mag_x  =df.iloc[:,3]
mag_y  =df.iloc[:,4]
mag_z  =df.iloc[:,5]
df
# Out:
#            2000  0.83  0.00  -671.46  375.64  -704.28
# 0          4000  0.78  0.22   629.34  377.20  -741.37
# 1          6000  0.79 -0.23   -40.17 -738.29  -735.70
# 2          8000  0.83  0.01  -651.34  410.07  -703.94
# 3         10000  0.78  0.22   647.02  344.40  -742.07
# 4         12000  0.79 -0.24   -76.99 -735.69  -735.33
# ...         ...   ...   ...      ...     ...      ...
# 39797  81224000  0.58  0.03  -294.50  398.42  -750.23
# 39798  81226000  0.57  0.05  -116.54  472.92  -754.87
# 39799  81228000  0.56  0.07    76.05  469.88  -761.08
# 39800  81230000  0.54  0.07   251.02  390.03  -767.74
# 39801  81232000  0.53  0.06   379.17  246.92  -773.67
#
# [39802 rows x 6 columns]

# %%
range_a = 10
range_b = 5000

# plt.plot(t[range_a:range_b], mag_x[range_a:range_b],".",label="mag_x")
# plt.plot(t[range_a:range_b], mag_y[range_a:range_b],".",label="mag_y")
# plt.plot(t[range_a:range_b], mag_z[range_a:range_b],".",label="mag_z")

# plt.plot(t[range_a:range_b], mag_z_v[range_a:range_b],".",label="mag_z vector")
# plt.xlabel("sec")
# plt.ylabel("Vector Strength")
# plt.legend()

plt.plot(t, error,label="pointing error")
plt.xlabel("s")
plt.ylabel("rads")
plt.legend()

# %%
plt.plot(t, current*400.0,label="pointing(z_mag) current(mA)")
plt.xlabel("sec")
plt.ylabel("mA")
plt.legend()

# %%
plt.plot(t, mag_x,label="mag_field_x")
plt.plot(t, mag_y,label="mag_field_y")
plt.plot(t, mag_z,label="mag_field_z")
plt.xlabel("sec")
plt.ylabel("uT")
plt.legend()
