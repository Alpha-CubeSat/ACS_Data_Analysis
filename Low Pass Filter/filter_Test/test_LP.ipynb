# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("test_Data1.txt")
mag_x_raw = df.iloc[:,0]
mag_x_LP = df.iloc[:,1]
x = np.arange(0,mag_x_raw.size)
t = x*0.25
df
# Out:
#      -17.50   -17.48   103.71   103.70   -35.62   -35.91
# 0    -17.47   -17.48   103.81   103.71   -35.81   -35.89
# 1    -17.44   -17.48   103.65   103.71   -36.06   -35.90
# 2    -17.50   -17.48   103.65   103.70   -35.87   -35.90
# 3    -17.57   -17.48   103.71   103.70   -35.90   -35.90
# 4    -17.47   -17.48   103.78   103.70   -35.87   -35.90
# ..      ...      ...      ...      ...      ...      ...
# 231   17.41    10.17   -73.28   -61.57    23.81    22.42
# 232   17.41    10.60   -73.09   -62.27    23.81    22.51
# 233   17.41    11.01   -73.22   -62.92    24.00    22.59
# 234   17.38    11.40   -73.28   -63.55    23.94    22.67
# 235   17.38    11.76   -73.34   -64.13    23.87    22.75
#
# [236 rows x 6 columns]

# %%
# sim = np.zeros(len(mag_x_raw))
#
# for i in range(3,len(mag_x_LP)):
#     sim[i] = 0.97581448 * sim[i-1] + 0.01209276*mag_x_raw[i] + 0.01209276*mag_x_raw[i-1]

# %%
# plt.plot(t[50:200],mag_x_raw[50:200],label="raw")
# plt.plot(t[50:200],mag_x_LP[50:200],label="LP smooth")
plt.plot(t,mag_x_raw,label="raw")
plt.plot(t,mag_x_LP,label="LP smooth")
plt.xlabel("sec")
plt.ylabel("uT")
plt.legend()
